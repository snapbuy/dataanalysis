# %% [markdown]
# ## 공공데이터를 이용한 카페 상권분석(2020 Ver.)
#
#
# **들어가며**
#
# - 공공데이터를 통해 대한민국을 이해해봅시다(?).
# - 공공데이터포털(data.go.kr)에 다양한 데이터가 공개되어 있습니다.
# - 그 중에 카페(라는 업종분류)들에 대해서 현황을 조사하려고 합니다.
#
# **명세사항**
# 1. 전국 카페 데이터를 모두 수집해야합니다.
# 2. 지역별 or 브랜드별 점포 현황을 확인합니다.
# 3. 분석 결과를 시각화합니다.
#
#
#
# [데이터] https://www.data.go.kr/data/15012005/fileData.do

# %%
# 라이브러리를 불러옵니다.
import pandas as pd

# %% [markdown]
# ### Data Load

# %%
# 다운로드 받은 데이터중 일부를 열어봅니다.
temp = pd.read_csv("data/소상공인시장진흥공단_상가(상권)정보_서울_202012.csv", sep='|')
temp
# Out:
#           상가업소번호        상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드    상권업종중분류명  \
# 0       17163092  도전최강달인왕만두  NaN         Q       음식       Q01          한식
# 1       17120456         이때  NaN         Q       음식       Q01          한식
# 2       17175350      L.A.D  NaN         Q       음식       Q01          한식
# 3       17175311    제이씨에스푸드  NaN         Q       음식       Q01          한식
# 4       22767534     BYC상신점  상신점         D       소매       D05        의복의류
# ...          ...        ...  ...       ...      ...       ...         ...
# 346572  17222727       현대기림  NaN         D       소매       D10     건강/미용식품
# 346573  17222723     본현대미아점  NaN         D       소매       D10     건강/미용식품
# 346574  17219564      오피스알파  약장수         D       소매       D10     건강/미용식품
# 346575  17219761  앤클라인뉴욕핸드백  NaN         D       소매       D06  가방/신발/액세서리
# 346576  17207617      피움테라피  NaN         F    생활서비스       F01     이/미용/건강
#
#        상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# 0         Q01A01  한식/백반/한정식   I56111  ...  1174010200102170000018014
# 1         Q01A01  한식/백반/한정식   I56111  ...  1144012400103900067027687
# 2         Q01A01  한식/백반/한정식   I56111  ...  1144012000103950112010755
# 3         Q01A01  한식/백반/한정식   I56111  ...  1162010200101180033018722
# 4         D05A07   셔츠/내의/속옷      NaN  ...  1171011300100360000022458
# ...          ...        ...      ...  ...                        ...
# 346572    D10A04     건강식품판매   G47216  ...  1120011400102760017009013
# 346573    D10A04     건강식품판매   G47216  ...  1129013400100200001025204
# 346574    D10A04     건강식품판매   G47216  ...  1130510300100360037035171
# 346575    D06A10  가방/가죽제품소매   G47430  ...  1153010200105730000020642
# 346576    F01A03    비만/피부관리      NaN  ...  1135010600105040001010530
#
#              건물명                  도로명주소   구우편번호   신우편번호  동정보  층정보  호정보  \
# 0         고덕그라시움      서울특별시 강동구 고덕로 333  134082  5224.0  NaN  NaN  NaN
# 1            NaN    서울특별시 마포구 동교로38안길 7  121867  3982.0  NaN  NaN  NaN
# 2            NaN   서울특별시 마포구 잔다리로3안길 23  121840  4043.0  NaN  NaN  NaN
# 3            NaN     서울특별시 관악구 신림로14길 3  151856  8839.0  NaN  NaN  NaN
# 4           성암빌딩      서울특별시 송파구 오금로 527  138110  5768.0  NaN    1  NaN
# ...          ...                    ...     ...     ...  ...  ...  ...
# 346572       NaN   서울특별시 성동구 뚝섬로 366-72  133819  4775.0  NaN  NaN  NaN
# 346573  현대백화점미아점     서울특별시 성북구 동소문로 315  136719  2730.0  NaN    5  NaN
# 346574       NaN  서울특별시 강북구 노해로17길 62-1  142872  1075.0  NaN  NaN  101
# 346575     NC백화점    서울특별시 구로구 구로중앙로 152  152715  8292.0  NaN    1  NaN
# 346576   중계그린아파트      서울특별시 노원구 섬밭로 285  139863  1773.0  NaN  NaN  207
#
#                 경도         위도
# 0       127.159471  37.556197
# 1       126.924660  37.562176
# 2       126.919845  37.550689
# 3       126.937790  37.471190
# 4       127.147321  37.493054
# ...            ...        ...
# 346572  127.051154  37.539464
# 346573  127.028726  37.608392
# 346574  127.018733  37.640485
# 346575  126.882409  37.501378
# 346576  127.062556  37.640913
#
# [346577 rows x 39 columns]

# %%
# data 폴더에 있는 모든 csv 파일을 읽어오기 위해 glob을 사용합니다.
from glob import glob

# csv 목록 불러오기
file_names = glob("data/*.csv")

total = pd.DataFrame()

# 모든 csv 병합하기
for file_name in file_names:
    temp = pd.read_csv(file_name, sep='|')
    total = pd.concat([total, temp])
    
# reset index
total.reset_index(inplace=True)
total.head()
# Out:
# /Users/emphimachine/opt/anaconda3/envs/fastcampus/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (35) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    index    상가업소번호    상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드   상권업종중분류명  \
# 0      0  17175332   정성밥상  NaN         Q       음식       Q01         한식
# 1      1  23206623    미광장  NaN         O       숙박       O02  모텔/여관/여인숙
# 2      2  20418637  BHC치킨  동래점         Q       음식       Q05     닭/오리요리
# 3      3  24659633    스텔라  NaN         D       소매       D05       의복의류
# 4      4  17174094   도란도란  NaN         Q       음식       Q01         한식
#
#   상권업종소분류코드   상권업종소분류명  ...                     건물관리번호    건물명  \
# 0    Q01A01  한식/백반/한정식  ...  2635010500105520002023290    NaN
# 1    O02A01  모텔/여관/여인숙  ...  2611012600100250001004473    NaN
# 2    Q05A08  후라이드/양념치킨  ...  2626010500101850000016529    NaN
# 3    D05A01       일반의류  ...  2650010500101480004001694  비치아파트
# 4    Q01A01  한식/백반/한정식  ...  2623011100101740004050547    NaN
#
#                        도로명주소     구우편번호    신우편번호  동정보  층정보  호정보          경도  \
# 0      부산광역시 해운대구 해운대로 635-7  612819.0  48087.0  NaN  NaN  NaN  129.159641
# 1        부산광역시 중구 보수대로44번길 5  600074.0  48974.0  NaN  NaN  NaN  129.023668
# 2      부산광역시 동래구 동래로147번길 18  607020.0  47802.0  NaN  NaN  NaN  129.087156
# 3        부산광역시 수영구 광안해변로 100  613751.0  48305.0  NaN  NaN   20  129.115397
# 4  부산광역시 부산진구 가야대로482번길 29-3  614813.0  47327.0  NaN  NaN  NaN  129.024938
#
#           위도
# 0  35.164474
# 1  35.100979
# 2  35.205267
# 3  35.143770
# 4  35.151645
#
# [5 rows x 40 columns]

# %%
total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2416252 entries, 0 to 2416251
# Data columns (total 40 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   index      int64
#  1   상가업소번호     int64
#  2   상호명        object
#  3   지점명        object
#  4   상권업종대분류코드  object
#  5   상권업종대분류명   object
#  6   상권업종중분류코드  object
#  7   상권업종중분류명   object
#  8   상권업종소분류코드  object
#  9   상권업종소분류명   object
#  10  표준산업분류코드   object
#  11  표준산업분류명    object
#  12  시도코드       int64
#  13  시도명        object
#  14  시군구코드      int64
#  15  시군구명       object
#  16  행정동코드      int64
#  17  행정동명       object
#  18  법정동코드      float64
#  19  법정동명       object
#  20  지번코드       int64
#  21  대지구분코드     int64
#  22  대지구분명      object
#  23  지번본번지      int64
#  24  지번부번지      float64
#  25  지번주소       object
#  26  도로명코드      int64
#  27  도로명        object
#  28  건물본번지      int64
#  29  건물부번지      float64
#  30  건물관리번호     object
#  31  건물명        object
#  32  도로명주소      object
#  33  구우편번호      float64
#  34  신우편번호      float64
#  35  동정보        object
#  36  층정보        object
#  37  호정보        object
#  38  경도         float64
#  39  위도         float64
# dtypes: float64(7), int64(10), object(23)
# memory usage: 737.4+ MB

# %%
# 분석에 필요한 column을 고릅니다. ## 자유롭게 하셔도 상관없습니다.
data = total[['상호명','지점명',
              '상권업종대분류명', '상권업종중분류명',
              '시도명', '시군구명', '행정동명',
              '위도', '경도']]

data.head()
# Out:
#      상호명  지점명 상권업종대분류명   상권업종중분류명    시도명  시군구명  행정동명         위도          경도
# 0   정성밥상  NaN       음식         한식  부산광역시  해운대구   우1동  35.164474  129.159641
# 1    미광장  NaN       숙박  모텔/여관/여인숙  부산광역시    중구   부평동  35.100979  129.023668
# 2  BHC치킨  동래점       음식     닭/오리요리  부산광역시   동래구   복산동  35.205267  129.087156
# 3    스텔라  NaN       소매       의복의류  부산광역시   수영구  남천2동  35.143770  129.115397
# 4   도란도란  NaN       음식         한식  부산광역시  부산진구  개금1동  35.151645  129.024938

# %%
data
# Out:
#              상호명  지점명 상권업종대분류명   상권업종중분류명    시도명  시군구명   행정동명         위도  \
# 0           정성밥상  NaN       음식         한식  부산광역시  해운대구    우1동  35.164474
# 1            미광장  NaN       숙박  모텔/여관/여인숙  부산광역시    중구    부평동  35.100979
# 2          BHC치킨  동래점       음식     닭/오리요리  부산광역시   동래구    복산동  35.205267
# 3            스텔라  NaN       소매       의복의류  부산광역시   수영구   남천2동  35.143770
# 4           도란도란  NaN       음식         한식  부산광역시  부산진구   개금1동  35.151645
# ...          ...  ...      ...        ...    ...   ...    ...        ...
# 2416247    아이지에이  논현점       소매      종합소매점  인천광역시   남동구  논현고잔동  37.395174
# 2416248  땡이네애견용품  NaN       소매   애견/애완/동물  인천광역시   남동구   구월3동  37.454645
# 2416249    인생건어물  NaN       소매    음/식료품소매  인천광역시  미추홀구   숭의2동  37.459209
# 2416250    착한건어물  NaN       소매    음/식료품소매  인천광역시   연수구   동춘2동  37.407286
# 2416251    더어려지다  NaN    생활서비스    이/미용/건강  인천광역시   연수구   송도2동  37.399113
#
#                  경도
# 0        129.159641
# 1        129.023668
# 2        129.087156
# 3        129.115397
# 4        129.024938
# ...             ...
# 2416247  126.723415
# 2416248  126.702129
# 2416249  126.643929
# 2416250  126.670416
# 2416251  126.637119
#
# [2416252 rows x 9 columns]

# %%
# 메모리 낭비를 막기 위해 필요없는 변수는 제거합니다.
del total

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# #### 전국 커피 전문점

# %%
# 카페만 뽑아냅니다.
df_coffee = data[(data['상권업종중분류명']=='커피점/카페')]
# index를 다시 세팅합니다.
df_coffee.index = range(len(df_coffee))
print("전국 커피 전문점 점포 수 : ", len(df_coffee))
df_coffee.head()
# Out:
# 전국 커피 전문점 점포 수 :  113705
#       상호명  지점명 상권업종대분류명 상권업종중분류명    시도명 시군구명  행정동명         위도          경도
# 0  투썸플레이스  대연점       음식   커피점/카페  부산광역시   남구  대연3동  35.135963  129.097701
# 1     더리터  수영점       음식   커피점/카페  부산광역시  수영구  남천1동  35.141748  129.107896
# 2    비움카페  NaN       음식   커피점/카페  부산광역시  기장군   기장읍  35.189328  129.221668
# 3     아망떼  NaN       음식   커피점/카페  부산광역시   북구  덕천2동  35.209860  129.006285
# 4    비니버니  NaN       음식   커피점/카페  부산광역시  금정구   서2동  35.214546  129.104689

# %% [markdown]
# #### 서울내 커피 전문점

# %%
# 카페 중에 "서울"에 위치하고 있는 점포만 뽑아냅니다.
df_seoul_coffee = data[(data['상권업종중분류명']=='커피점/카페')&(data['시도명']=='서울특별시')]
df_seoul_coffee.index = range(len(df_seoul_coffee))
print('서울시 내 커피 전문점 점포 수 :', len(df_seoul_coffee))
df_seoul_coffee.head()
# Out:
# 서울시 내 커피 전문점 점포 수 : 22239
#         상호명          지점명 상권업종대분류명 상권업종중분류명    시도명 시군구명  행정동명         위도  \
# 0       커피빈  코리아대학로대명거리점       음식   커피점/카페  서울특별시  종로구   혜화동  37.583149
# 1     요거프레소          쌍문점       음식   커피점/카페  서울특별시  도봉구  쌍문2동  37.658728
# 2  406번째스토브          NaN       음식   커피점/카페  서울특별시  양천구   목1동  37.525177
# 3     로얄커피숍          NaN       음식   커피점/카페  서울특별시  강동구  성내2동  37.534901
# 4    빈트리망원점          망원점       음식   커피점/카페  서울특별시  마포구  망원1동  37.556041
#
#            경도
# 0  127.000171
# 1  127.034746
# 2  126.874168
# 3  127.124193
# 4  126.899339

# %% [markdown]
# #### 전국 스타벅스

# %%
# 이번엔 전국에 있는 스타벅스를 뽑아냅니다.
df_starbucks = df_coffee[df_coffee['상호명'].str.contains('스타벅스')]
df_starbucks.index = range(len(df_starbucks))
print('전국 스타벅스 점포 수 :', len(df_starbucks))
df_starbucks.head()
# Out:
# 전국 스타벅스 점포 수 : 1613
#          상호명     지점명 상권업종대분류명 상권업종중분류명    시도명  시군구명  행정동명         위도  \
# 0       스타벅스    부산역점       음식   커피점/카페  부산광역시    동구  초량3동  35.116346
# 1       스타벅스  부산연산역점       음식   커피점/카페  부산광역시   연제구  연산4동  35.186967
# 2       스타벅스  연산중앙로점       음식   커피점/카페  부산광역시   연제구  연산5동  35.185431
# 3       스타벅스   부산하단점       음식   커피점/카페  부산광역시   사하구  하단1동  35.105350
# 4  스타벅스서면NC점   서면NC점       음식   커피점/카페  부산광역시  부산진구  전포1동  35.157050
#
#            경도
# 0  129.040831
# 1  129.083344
# 2  129.080677
# 3  128.968878
# 4  129.063037

# %% [markdown]
# #### 서울 스타벅스

# %%
# 이번엔 서울에 있는 스타벅스를 뽑아냅니다.
df_seoul_starbucks = df_seoul_coffee[df_seoul_coffee['상호명'].str.contains('스타벅스')]
df_seoul_starbucks.index = range(len(df_seoul_starbucks))
print('서울시 내 스타벅스 점포 수 :', len(df_seoul_starbucks))
df_seoul_starbucks.head()
# Out:
# 서울시 내 스타벅스 점포 수 : 509
#            상호명      지점명 상권업종대분류명 상권업종중분류명    시도명 시군구명  행정동명         위도  \
# 0         스타벅스     대학로점       음식   커피점/카페  서울특별시  종로구   이화동  37.582185
# 1         스타벅스      한티점       음식   커피점/카페  서울특별시  강남구  대치4동  37.497946
# 2         스타벅스   동숭로아트점       음식   커피점/카페  서울특별시  종로구   이화동  37.582964
# 3  스타벅스남부터미널2점  남부터미널2점       음식   커피점/카페  서울특별시  서초구  서초3동  37.484386
# 4         스타벅스    가로수길점       음식   커피점/카페  서울특별시  강남구   신사동  37.523184
#
#            경도
# 0  127.002233
# 1  127.053715
# 2  127.003887
# 3  127.014198
# 4  127.021629

# %% [markdown]
# #### 전국 이디야

# %%
df_ediya = df_coffee[df_coffee['상호명'].str.contains('이디야')]
df_ediya.index = range(len(df_ediya))
print('전국 이디야 점포 수 :', len(df_ediya))
df_ediya.head()
# Out:
# 전국 이디야 점포 수 : 2238
#      상호명     지점명 상권업종대분류명 상권업종중분류명    시도명  시군구명  행정동명         위도          경도
# 0  이디야커피  반송도서관점       음식   커피점/카페  부산광역시  해운대구  반송1동  35.225032  129.148858
# 1  이디야커피  부산다대포점       음식   커피점/카페  부산광역시   사하구  다대1동  35.048200  128.966690
# 2  이디야커피  부산초량역점       음식   커피점/카페  부산광역시    동구  초량3동  35.121133  129.043920
# 3  이디야커피     장림점       음식   커피점/카페  부산광역시   사하구  장림2동  35.080463  128.974461
# 4  이디야커피  부산신만덕점       음식   커피점/카페  부산광역시    북구  만덕2동  35.209767  129.036574

# %% [markdown]
# #### 서울 이디야

# %%
df_seoul_ediya = df_seoul_coffee[df_seoul_coffee['상호명'].str.contains('이디야')]
df_seoul_ediya.index = range(len(df_seoul_ediya))
print('서울시 내 이디야 점포 수 :', len(df_seoul_ediya))
df_seoul_ediya.head()
# Out:
# 서울시 내 이디야 점포 수 : 474
#           상호명    지점명 상권업종대분류명 상권업종중분류명    시도명  시군구명  행정동명         위도  \
# 0       이디야커피   신길역점       음식   커피점/카페  서울특별시  영등포구  신길1동  37.515118
# 1       이디야커피   북창동점       음식   커피점/카페  서울특별시    중구   소공동  37.563637
# 2       이디야커피   라이프점       음식   커피점/카페  서울특별시  영등포구   여의동  37.519544
# 3       이디야커피    시흥점       음식   커피점/카페  서울특별시   금천구  시흥2동  37.449066
# 4  이디야커피양재AT점  양재AT점       음식   커피점/카페  서울특별시   서초구  양재2동  37.469075
#
#            경도
# 0  126.918062
# 1  126.977556
# 2  126.939198
# 3  126.913646
# 4  127.040265

# %% [markdown]
# #### 전국 커피빈

# %%
df_coffeebean = df_coffee[df_coffee['상호명'].str.contains('커피빈')]
df_coffeebean.index = range(len(df_coffeebean))
print('전국 커피빈 점포 수 :', len(df_coffeebean))
df_coffeebean.head()
# Out:
# 전국 커피빈 점포 수 : 324
#             상호명           지점명 상권업종대분류명 상권업종중분류명    시도명  시군구명  행정동명         위도  \
# 0           커피빈       부산무역센터점       음식   커피점/카페  부산광역시    중구   중앙동  35.105835
# 1           커피빈  코리아해운대한화콘도앞점       음식   커피점/카페  부산광역시  해운대구   우1동  35.154032
# 2           커피빈   코리아부산화명수정역점       음식   커피점/카페  부산광역시    북구  화명1동  35.224201
# 3  커피빈코리아부산수영역점     코리아부산수영역점       음식   커피점/카페  부산광역시   수영구  광안3동  35.165376
# 4      커피빈부산정관점         부산정관점       음식   커피점/카페  부산광역시   기장군   정관읍  35.321933
#
#            경도
# 0  129.037758
# 1  129.145861
# 2  129.008516
# 3  129.114506
# 4  129.175654

# %% [markdown]
# #### 서울 커피빈

# %%
df_seoul_coffeebean = df_seoul_coffee[df_seoul_coffee['상호명'].str.contains('커피빈')]
df_seoul_coffeebean.index = range(len(df_seoul_coffeebean))
print('서울시 내 커피빈 점포 수 :', len(df_seoul_coffeebean))
df_seoul_coffeebean.head()
# Out:
# 서울시 내 커피빈 점포 수 : 191
#            상호명          지점명 상권업종대분류명 상권업종중분류명    시도명 시군구명  행정동명         위도  \
# 0          커피빈  코리아대학로대명거리점       음식   커피점/카페  서울특별시  종로구   혜화동  37.583149
# 1          커피빈      코리아선릉역점       음식   커피점/카페  서울특별시  강남구  역삼1동  37.504750
# 2  커피빈코리아낙성대역점     코리아낙성대역점       음식   커피점/카페  서울특별시  관악구   행운동  37.478106
# 3          커피빈     코리아청담에스점       음식   커피점/카페  서울특별시  강남구   청담동  37.525250
# 4          커피빈     코리아청담성당점       음식   커피점/카페  서울특별시  강남구   청담동  37.519902
#
#            경도
# 0  127.000171
# 1  127.048223
# 2  126.961593
# 3  127.047216
# 4  127.050021

# %% [markdown]
# #### 전국 투썸

# %%
df_2some = df_coffee[df_coffee['상호명'].str.contains('투썸')]
df_2some.index = range(len(df_2some))
print('전국 투썸플레이스 점포 수 :', len(df_2some))
df_2some.head()
# Out:
# 전국 투썸플레이스 점포 수 : 1141
#                 상호명         지점명 상권업종대분류명 상권업종중분류명    시도명  시군구명  행정동명  \
# 0            투썸플레이스         대연점       음식   커피점/카페  부산광역시    남구  대연3동
# 1            투썸플레이스    센텀스카이비즈점       음식   커피점/카페  부산광역시  해운대구  재송1동
# 2  투썸플레이스부산명지국제신도시점  부산명지국제신도시점       음식   커피점/카페  부산광역시   강서구   명지동
# 3            투썸플레이스        벡스코점       음식   커피점/카페  부산광역시  해운대구   우2동
# 4            투썸플레이스         NaN       음식   커피점/카페  부산광역시   사상구   괘법동
#
#           위도          경도
# 0  35.135963  129.097701
# 1  35.175207  129.124597
# 2  35.097756  128.919641
# 3  35.166531  129.133775
# 4  35.160841  128.984540

# %% [markdown]
# #### 서울 투썸

# %%
df_seoul_2some = df_seoul_coffee[df_seoul_coffee['상호명'].str.contains('투썸')]
df_seoul_2some.index = range(len(df_seoul_2some))
print('서울시 내 투썸플레이스 점포 수 :', len(df_seoul_2some))
df_seoul_2some.head()
# Out:
# 서울시 내 투썸플레이스 점포 수 : 286
#              상호명                지점명 상권업종대분류명 상권업종중분류명    시도명 시군구명   행정동명  \
# 0         투썸플레이스              서울타워점       음식   커피점/카페  서울특별시  용산구  용산2가동
# 1  투썸플레이스서울대역중앙점            서울대역중앙점       음식   커피점/카페  서울특별시  관악구    중앙동
# 2         투썸플레이스  씨제이프레시웨이강남세브란스병원점       음식   커피점/카페  서울특별시  강남구   도곡1동
# 3         투썸플레이스           LG광화문빌딩점       음식   커피점/카페  서울특별시  종로구    사직동
# 4         투썸플레이스             가락시장역점       음식   커피점/카페  서울특별시  송파구   가락본동
#
#           위도          경도
# 0  37.551111  126.987856
# 1  37.481879  126.952190
# 2  37.492795  127.046294
# 3  37.569262  126.971558
# 4  37.493986  127.120826

# %% [markdown]
# #### 전국 빽다방

# %%
df_bbaek = df_coffee[df_coffee['상호명'].str.contains('빽다방')]
df_bbaek.index = range(len(df_bbaek))
print('전국 빽다방 점포 수 :', len(df_bbaek))
df_bbaek.head()
# Out:
# 전국 빽다방 점포 수 : 567
#         상호명      지점명 상권업종대분류명 상권업종중분류명    시도명  시군구명  행정동명         위도  \
# 0       빽다방   부산광복로점       음식   커피점/카페  부산광역시    중구   남포동  35.098883
# 1       빽다방      NaN       음식   커피점/카페  부산광역시  부산진구  부전2동  35.153852
# 2       빽다방   부산구남역점       음식   커피점/카페  부산광역시    북구  구포2동  35.198037
# 3       빽다방  서면영광도서점       음식   커피점/카페  부산광역시  부산진구  부전1동  35.158651
# 4  빽다방부산대역점    부산대역점       음식   커피점/카페  부산광역시   금정구  장전3동  35.229589
#
#            경도
# 0  129.031692
# 1  129.060746
# 2  128.996135
# 3  129.057197
# 4  129.088898

# %% [markdown]
# #### 서울 빽다방

# %%
df_seoul_bbaek = df_seoul_coffee[df_seoul_coffee['상호명'].str.contains('빽다방')]
df_seoul_bbaek.index = range(len(df_seoul_bbaek))
print('서울시 내 빽다방 점포 수 :', len(df_seoul_bbaek))
df_seoul_bbaek.head()
# Out:
# 서울시 내 빽다방 점포 수 : 129
#            상호명     지점명 상권업종대분류명 상권업종중분류명    시도명 시군구명  행정동명         위도  \
# 0  더본코리아_빽다방등촌     성당점       음식   커피점/카페  서울특별시  강서구  등촌3동  37.560224
# 1  스시마이우강남역빽다방     NaN       음식   커피점/카페  서울특별시  서초구  서초4동  37.498120
# 2    빽다방공덕새창로점  공덕새창로점       음식   커피점/카페  서울특별시  마포구   도화동  37.542228
# 3     빽다방서초우성점   서초우성점       음식   커피점/카페  서울특별시  서초구  서초2동  37.493026
# 4    빽다방잠실장미상가     NaN       음식   커피점/카페  서울특별시  송파구  잠실6동  37.519810
#
#            경도
# 0  126.845764
# 1  127.025259
# 2  126.951822
# 3  127.029306
# 4  127.099289

# %% [markdown]
# #### 전국 할리스

# %%
df_hollys = df_coffee[df_coffee['상호명'].str.contains('할리스')]
df_hollys.index = range(len(df_hollys))
print('전국 할리스 점포 수 :', len(df_hollys))
df_hollys.head()
# Out:
# 전국 할리스 점포 수 : 707
#            상호명      지점명 상권업종대분류명 상권업종중분류명    시도명 시군구명  행정동명         위도  \
# 0        할리스커피    부산교대점       음식   커피점/카페  부산광역시  동래구   수민동  35.197133
# 1        할리스커피  부산명륜자이점       음식   커피점/카페  부산광역시  동래구   명륜동  35.208761
# 2  할리스커피일광해안로점   일광해안로점       음식   커피점/카페  부산광역시  기장군   일광면  35.275144
# 3        할리스커피    부산대역점       음식   커피점/카페  부산광역시  금정구  장전3동  35.230803
# 4     할리스커피사상점      사상점       음식   커피점/카페  부산광역시  사상구   괘법동  35.161699
#
#            경도
# 0  129.083534
# 1  129.081470
# 2  129.255457
# 3  129.088156
# 4  128.986548

# %% [markdown]
# #### 서울 할리스

# %%
df_seoul_hollys = df_seoul_coffee[df_seoul_coffee['상호명'].str.contains('할리스')]
df_seoul_hollys.index = range(len(df_seoul_hollys))
print('서울시 내 할리스 점포 수 :', len(df_seoul_hollys))
df_seoul_hollys.head()
# Out:
# 서울시 내 할리스 점포 수 : 200
#            상호명     지점명 상권업종대분류명 상권업종중분류명    시도명  시군구명  행정동명         위도  \
# 0   할리스커피남부터미널     NaN       음식   커피점/카페  서울특별시   서초구  서초1동  37.486724
# 1          할리스  백석예술대점       음식   커피점/카페  서울특별시   서초구  방배3동  37.480366
# 2          할리스    국기원점       음식   커피점/카페  서울특별시   강남구  역삼1동  37.499633
# 3  할리스커피KBS본관점  KBS본관점       음식   커피점/카페  서울특별시  영등포구   여의동  37.526017
# 4        할리스커피     선릉점       음식   커피점/카페  서울특별시   강남구  대치4동  37.503362
#
#            경도
# 0  127.015739
# 1  126.996884
# 2  127.029582
# 3  126.918674
# 4  127.050514

# %% [markdown]
# #### 전국 메가커피

# %%
df_mega = df_coffee[df_coffee['상호명'].str.contains('메가커피')]
df_mega.index = range(len(df_mega))
print('전국 메가커피 점포 수 :', len(df_mega))
df_mega.head()
# Out:
# 전국 메가커피 점포 수 : 481
#        상호명     지점명 상권업종대분류명 상권업종중분류명    시도명  시군구명  행정동명         위도          경도
# 0     메가커피  해운대해변점       음식   커피점/카페  부산광역시  해운대구   중1동  35.160260  129.161996
# 1  메가커피반여점     반여점       음식   커피점/카페  부산광역시  해운대구  반여2동  35.197814  129.131333
# 2     메가커피  해운대좌동점       음식   커피점/카페  부산광역시  해운대구   좌4동  35.179334  129.174069
# 3     메가커피     NaN       음식   커피점/카페  부산광역시   사하구  하단2동  35.107377  128.967981
# 4     메가커피    사직역점       음식   커피점/카페  부산광역시   동래구  사직1동  35.197331  129.065308

# %% [markdown]
# #### 서울 메가커피

# %%
df_seoul_mega = df_seoul_coffee[df_seoul_coffee['상호명'].str.contains('메가커피')]
df_seoul_mega.index = range(len(df_seoul_mega))
print('서울시 내 메가커피 점포 수 :', len(df_seoul_mega))
df_seoul_mega.head()
# Out:
# 서울시 내 메가커피 점포 수 : 86
#       상호명     지점명 상권업종대분류명 상권업종중분류명    시도명  시군구명 행정동명         위도          경도
# 0  메가커피미아   수유시장점       음식   커피점/카페  서울특별시   강북구  미아동  37.630164  127.023695
# 1    메가커피     홍대점       음식   커피점/카페  서울특별시   마포구  서교동  37.552433  126.921359
# 2    메가커피     NaN       음식   커피점/카페  서울특별시  동대문구  용신동  37.576200  127.023642
# 3    메가커피     NaN       음식   커피점/카페  서울특별시   금천구  가산동  37.479628  126.887266
# 4    메가커피  숙대입구역점       음식   커피점/카페  서울특별시   용산구  남영동  37.543056  126.972201

# %% [markdown]
# ## 커피전문점 별 비율 비교

# %% [markdown]
# **2020년 12월 기준 커피전문점 평판 순위**
#
#
# (source : https://www.futurekorea.co.kr/news/articleView.html?idxno=125637)

# %% [markdown]
# 1. 스타벅스
# 2. 투썸플레이스
# 3. 이디야
# 4. 메가커피
# 5. 커피빈

# %% [markdown]
# **변수**
#
# - 전체 점포 : data
# - 전체/서울 커피전문점 : df_coffee / df_seoul_starbucks
#
#
#
# - 전체/서울 스타벅스 : df_starbucks / df_seoul_starbucks
# - 전체/서울 이디야 : df_ediya / df_seoul_ediya
# - 전체/서울 커피빈 : df_coffeebean / df_seoul_coffeebean
# - 전체/서울 투썸플레이스 : df_2some / df_seoul_2some
# - 전체/서울 빽다방 : df_bbaek / df_seoul_bbaek
# - 전체/서울 할리스 : df_hollys / df_seoul_hollys
# - 전체/서울 메가커피 : df_mega / df_seoul_mega

# %% [markdown]
# ### 1. 전체 커피전문점 내 주요 커피브랜드 입점 비율

# %%
print("**** 전국 커피전문점중 주요 5대 커피브랜드 입점 비율 ****")
print("주요 5대 커피브랜드 전국 입점 비율 : %.3f%%" % ((len(df_starbucks) + len(df_2some)
                                        + len(df_ediya) + len(df_mega) + len(df_coffeebean)) / len(df_coffee)
                                        * 100))
print("1. 스타벅스 : %.3f%%" % (len(df_starbucks) / len(df_coffee) * 100))
print("2. 투썸플레이스 : %.3f%%" % (len(df_2some) / len(df_coffee) * 100))
print("3. 이디야 : %.3f%%" % (len(df_ediya) / len(df_coffee) * 100))
print("4. 메가커피 : %.3f%%" % (len(df_mega) / len(df_coffee) * 100))
print("5. 커피빈 : %.3f%%" % (len(df_coffeebean) / len(df_coffee) * 100))
# Out:
# **** 전국 커피전문점중 주요 5대 커피브랜드 입점 비율 ****
# 주요 5대 커피브랜드 전국 입점 비율 : 5.098%
# 1. 스타벅스 : 1.419%
# 2. 투썸플레이스 : 1.003%
# 3. 이디야 : 1.968%
# 4. 메가커피 : 0.423%
# 5. 커피빈 : 0.285%

# %% [markdown]
# ### 2. 서울 커피전문점 내 주요 커피브랜드 입점 비율

# %%
print("스타벅스 : %.3f%%" % (len(df_seoul_starbucks) / len(df_seoul_coffee) * 100))
print("이디야 : %.3f%%" % (len(df_seoul_ediya) / len(df_seoul_coffee) * 100))
print("커피빈 : %.3f%%" % (len(df_seoul_coffeebean) / len(df_seoul_coffee) * 100))
print("투썸플레이스 : %.3f%%" % (len(df_seoul_2some) / len(df_seoul_coffee) * 100))
print("빽다방 : %.3f%%" % (len(df_seoul_bbaek) / len(df_seoul_coffee) * 100))
print("할리스 : %.3f%%" % (len(df_seoul_hollys) / len(df_seoul_coffee) * 100))
print("메가커피 : %.3f%%" % (len(df_seoul_mega) / len(df_seoul_coffee) * 100))
# Out:
# 스타벅스 : 2.289%
# 이디야 : 2.131%
# 커피빈 : 0.859%
# 투썸플레이스 : 1.286%
# 빽다방 : 0.580%
# 할리스 : 0.899%
# 메가커피 : 0.387%

# %% [markdown]
# ### 3. 각 커피브랜드별 서울 입점 비율

# %%
print("**** 주요 5대 커피브랜드별 서울 입점 비율 ****")
print("1. 스타벅스 : %.3f%%" % (len(df_seoul_starbucks) / len(df_starbucks) * 100))
print("2. 투썸플레이스 : %.3f%%" % (len(df_seoul_2some) / len(df_2some) * 100))
print("3. 이디야 : %.3f%%" % (len(df_seoul_ediya) / len(df_ediya) * 100))
print("4. 메가커피 : %.3f%%" % (len(df_seoul_mega) / len(df_mega) * 100))
print("5. 커피빈 : %.3f%%" % (len(df_seoul_coffeebean) / len(df_coffeebean) * 100))
# Out:
# **** 주요 5대 커피브랜드별 서울 입점 비율 ****
# 1. 스타벅스 : 31.556%
# 2. 투썸플레이스 : 25.066%
# 3. 이디야 : 21.180%
# 4. 메가커피 : 17.879%
# 5. 커피빈 : 58.951%

# %%
starbucks_gu = df_seoul_starbucks.groupby('시군구명')['상호명'].count().to_frame().sort_values(by='상호명', ascending=False)
starbucks_gu = starbucks_gu.reset_index()
starbucks_gu = starbucks_gu.set_index('시군구명')
starbucks_gu
# Out:
#       상호명
# 시군구명
# 강남구    87
# 중구     48
# 서초구    44
# 송파구    33
# 종로구    31
# 마포구    28
# 영등포구   26
# 용산구    21
# 서대문구   21
# 강서구    19
# 광진구    17
# 강동구    15
# 성북구    15
# 금천구    12
# 양천구    12
# 노원구    11
# 동작구    11
# 관악구    11
# 구로구     9
# 은평구     9
# 성동구     8
# 동대문구    7
# 중랑구     7
# 강북구     5
# 도봉구     2

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import platform

from matplotlib import font_manager, rc
# %matplotlib inline

# %%
#### Windows10 사용자는 해당 코드가 필요없습니다!

# macos에서 사용가능한 한글 글꼴 확인 코드
[f.name for f in font_manager.fontManager.ttflist if 'Neo' in f.name]
# Out:
# ['Apple SD Gothic Neo']

# %%
## 운영체제별 글꼴 세팅

path = "c:/Windows/Fonts/malgun.ttf"
if platform.system() == 'Darwin':
    font_name = 'Apple SD Gothic Neo'
    rc('font', family='Apple SD Gothic Neo')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    font_name = font_manager.FontProperties(fname="/usr/share/fonts/nanumfont/NanumGothic.ttf")
    rc('font', family="NanumGothic")

# %%
starbucks_rate = (len(df_seoul_starbucks) / len(df_seoul_coffee) * 100)
twosome_rate = (len(df_seoul_2some) / len(df_seoul_coffee) * 100)
ediya_rate = (len(df_seoul_ediya) / len(df_seoul_coffee) * 100)
mega_rate = (len(df_seoul_mega) / len(df_seoul_coffee) * 100)
coffeebean_rate = (len(df_seoul_coffeebean) / len(df_seoul_coffee) * 100)


X = ['스타벅스', '투썸플레이스', '이디야', '메가커피', '커피빈']
y = [starbucks_rate, twosome_rate, ediya_rate, mega_rate, coffeebean_rate]

plt.figure(figsize=(12, 12))
plt.title("주요 5대 커피브랜드 서울 입점 비율", fontdict={'fontsize':20})
sns.barplot(x=X, y=y)
plt.savefig("coffee_barplot.png")
plt.show()

# %% [markdown]
# ### (Challenge) More Prettier!

# %%
# 위의 barplot을 seaborn을 이용하여 더욱 멋지게 시각화해보세요!
